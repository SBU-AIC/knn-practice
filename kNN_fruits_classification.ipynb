# %% [markdown]
# Reference: [kaggle notebook](https://www.kaggle.com/code/mjamilmoughal/k-nearest-neighbor-classifier-to-predict-fruits/notebook)

# %%
# @markdown Import Necessaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# @markdown load data
from tqdm.notebook import tqdm
import os

progress = tqdm(total=1)

# !wget https://raw.githubusercontent.com/SBU-AIC/knn-practice/main/fruits.txt -q

progress.set_description(f"Downloading file")
progress.update(1)

progress.close()

fruits=pd.read_table('fruits.txt')
fruits = fruits.drop(['color_score', 'fruit_subtype'], axis=1)

fruits.head()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#    fruit_label fruit_name  mass  width  height
# 0            1      apple   192    8.4     7.3
# 1            1      apple   180    8.0     6.8
# 2            1      apple   176    7.4     7.2
# 3            2   mandarin    86    6.2     4.7
# 4            2   mandarin    84    6.0     4.6

# %%
fruits['fruit_name'].value_counts()
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
# @markdown Apple
fruits[fruits['fruit_name']=='apple'].head()
# Out:
#    fruit_label fruit_name  mass  width  height
# 0            1      apple   192    8.4     7.3
# 1            1      apple   180    8.0     6.8
# 2            1      apple   176    7.4     7.2
# 8            1      apple   178    7.1     7.8
# 9            1      apple   172    7.4     7.0

# %%
# @markdown Mandarin
fruits[fruits['fruit_name']=='mandarin'].head()
# Out:
#    fruit_label fruit_name  mass  width  height
# 3            2   mandarin    86    6.2     4.7
# 4            2   mandarin    84    6.0     4.6
# 5            2   mandarin    80    5.8     4.3
# 6            2   mandarin    80    5.9     4.3
# 7            2   mandarin    76    5.8     4.0

# %%
# @markdown Orange
fruits[fruits['fruit_name']=='orange'].head()
# Out:
#     fruit_label fruit_name  mass  width  height
# 24            3     orange   342    9.0     9.4
# 25            3     orange   356    9.2     9.2
# 26            3     orange   362    9.6     9.2
# 27            3     orange   204    7.5     9.2
# 28            3     orange   140    6.7     7.1

# %%
# @markdown Lemon
fruits[fruits['fruit_name']=='lemon'].head()
# Out:
#     fruit_label fruit_name  mass  width  height
# 43            4      lemon   194    7.2    10.3
# 44            4      lemon   200    7.3    10.5
# 45            4      lemon   186    7.2     9.2
# 46            4      lemon   216    7.3    10.2
# 47            4      lemon   196    7.3     9.7

# %%
X = fruits.drop('fruit_label', axis=1)
Y = fruits['fruit_label']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#    fruit_name  mass  width  height
# 36     orange   160    7.1     7.6
# 31     orange   210    7.8     8.0
# 8       apple   178    7.1     7.8
# 17      apple   168    7.5     7.6
# 6    mandarin    80    5.9     4.3

# %%
def knnClassifier():
    ############################################################################
    ## TODO: define fit, score and predict methods.
    ## TODO: define k attribute
    raise NotImplementedError("Please complete this exercise")
    ############################################################################

# %%
############################################################################
## TODO: find the best k value
raise NotImplementedError("Please complete this part and choose the best value of k with error plot")
############################################################################

knn = knnClassifier(...)

# %%
knn.fit(X_train,y_train)

# %%
knn.score(X_test,y_test)

# %%
pred = knn.predict([['196','7.3','9.7']])
pred
# Out:
# 'lemon'

# %%
target = fruits.iloc[47]['fruit_name']
target
# Out:
# 'lemon'
